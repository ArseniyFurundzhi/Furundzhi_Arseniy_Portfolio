# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (10, 10))

#зададим аргумент и модуль комплексного числа
phi = np.linspace(0, 6*np.pi, 500)
rho = 0.9*abs(np.cos(1/6 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))

#построение исходной розы
plt.plot(z.real, z.imag, color = 'red', linewidth = 0.8)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")


#построение границы исходной розы
phi_1 = np.linspace(-np.pi, np.pi, 200)
rho = 0.9*abs(np.cos(1/6 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

#построение координатной сетки до отображения
x = np.linspace(-1, 1, 100)
y = np.linspace(0, 0, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(0.25, 0.25, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(0.5, 0.5, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(0.75, 0.75, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(-0.25, -0.25, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(-0.5, -0.5, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(-0.75, -0.75, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, -1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 100)
y = np.linspace(-1, 1, 100)
plt.plot(x, y, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#модуль, аргумент и отображение комплексного числа
phi = np.linspace(0, 6*np.pi, 500)
rho = 0.9*abs(np.cos(1/6 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))
f = 1j*np.arcsinh(z)


#построение образа розы
plt.plot(f.real, f.imag, color = 'orange', linewidth = 0.8)

plt.xlabel("Re(f(z))")
plt.ylabel("Im(f(z))")


#построение образа границы розы
phi_1 = np.linspace(-np.pi, np.pi, 200)
rho = 0.9*abs(np.cos(1/6 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)


#построение новой координатной сетки
x = np.linspace(-2, 2, 100)
y = np.linspace(0, 0, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(0.25, 0.25, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(0.5, 0.5, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(0.75, 0.75, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(1, 1, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(1.25, 1.25, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(-0.25, -0.25, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(-0.5, -0.5, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(-0.75, -0.75, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(-1, -1, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 100)
y = np.linspace(-1.25, -1.25, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(1, 1, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(1.25, 1.25, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1, -1, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1.25, -1.25, 100)
y = np.linspace(-2, 2, 100)
z = x + 1j * y
f = 1j*np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

plt.xlim(-1.25, 1.25)
plt.ylim(-1.25, 1.25)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#построение меньшей границы
phi = np.linspace(0, 4*np.pi, 400)
rho_1 = 0.3*abs(np.cos(3/4 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'red', linewidth = 2)

#построение большей границы
phi = np.linspace(0, 14*np.pi, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'orange', linewidth = 2)

#граница области
phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_4 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_5 = np.linspace(-np.pi/4 + 7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_6 = np.linspace(-np.pi/4 + 14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_7 = np.linspace(-np.pi/4 + 21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

plt.show()

# %% [markdown]
# Оставим только границу области.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#раскраска
theta_1 = np.linspace(0, np.pi/4, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_1))
rho_2 = 0.8*abs(np.cos(2/7 * theta_1))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_1) + 1j * np.sin(theta_1))
plt.plot(z.real, z.imag, color = 'salmon')

theta_2 = np.linspace(-np.pi/4 + 21*np.pi/2, 21*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_2))
rho_2 = 0.8*abs(np.cos(2/7 * theta_2))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_2) + 1j * np.sin(theta_2))
plt.plot(z.real, z.imag, color = 'red')

theta_3 = np.linspace(21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_3))
rho_2 = 0.8*abs(np.cos(2/7 * theta_3))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_3) + 1j * np.sin(theta_3))
plt.plot(z.real, z.imag, color = 'firebrick')

theta_4 = np.linspace(-np.pi/4 + 14*np.pi/2, 14*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_4))
rho_2 = 0.8*abs(np.cos(2/7 * theta_4))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_4) + 1j * np.sin(theta_4))
plt.plot(z.real, z.imag, color = 'darkred')

theta_5 = np.linspace(-np.pi/4, 0, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_5))
rho_2 = 0.8*abs(np.cos(2/7 * theta_5))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_5) + 1j * np.sin(theta_5))
plt.plot(z.real, z.imag, color = 'cornflowerblue')

theta_6 = np.linspace(7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_6))
rho_2 = 0.8*abs(np.cos(2/7 * theta_6))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_6) + 1j * np.sin(theta_6))
plt.plot(z.real, z.imag, color = 'blue')

theta_7 = np.linspace(-np.pi/4 + 7*np.pi/2, 7*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_7))
rho_2 = 0.8*abs(np.cos(2/7 * theta_7))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_7) + 1j * np.sin(theta_7))
plt.plot(z.real, z.imag, color = 'mediumblue')

theta_8 = np.linspace(14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_8))
rho_2 = 0.8*abs(np.cos(2/7 * theta_8))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_8) + 1j * np.sin(theta_8))
plt.plot(z.real, z.imag, color = 'darkblue')


#уберем лишнее внутри малой розы
phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
lines = np.linspace(0, rho_1, 800)
z = lines * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'white')

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
lines = np.linspace(0, rho_1, 800)
z = lines * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'white')

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
lines = np.linspace(0, rho_1, 800)
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'white')


phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_4 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_5 = np.linspace(-np.pi/4 + 7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_6 = np.linspace(-np.pi/4 + 14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

phi_7 = np.linspace(-np.pi/4 + 21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#построение образа меньшей границы
phi = np.linspace(0, 4*np.pi, 400)
rho_1 = 0.3*abs(np.cos(3/4 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'red', linewidth = 2)

#построение образа большей границы
phi = np.linspace(0, 14*np.pi, 2500)
rho_2 = 0.8*abs(np.cos(2/7 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'orange', linewidth = 2)

#построение образа границы области
phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_4 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_5 = np.linspace(-np.pi/4 + 7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_6 = np.linspace(-np.pi/4 + 14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_7 = np.linspace(-np.pi/4 + 21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

plt.show()

# %% [markdown]
# Оставим только образ границы области.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#раскраска образа
theta_1 = np.linspace(0, np.pi/4, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_1))
rho_2 = 0.8*abs(np.cos(2/7 * theta_1))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_1) + 1j * np.sin(theta_1))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'salmon')

theta_2 = np.linspace(-np.pi/4 + 21*np.pi/2, 21*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_2))
rho_2 = 0.8*abs(np.cos(2/7 * theta_2))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_2) + 1j * np.sin(theta_2))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'red')

theta_3 = np.linspace(21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_3))
rho_2 = 0.8*abs(np.cos(2/7 * theta_3))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_3) + 1j * np.sin(theta_3))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'firebrick')

theta_4 = np.linspace(-np.pi/4 + 14*np.pi/2, 14*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_4))
rho_2 = 0.8*abs(np.cos(2/7 * theta_4))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_4) + 1j * np.sin(theta_4))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'darkred')

theta_5 = np.linspace(-np.pi/4, 0, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_5))
rho_2 = 0.8*abs(np.cos(2/7 * theta_5))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_5) + 1j * np.sin(theta_5))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'cornflowerblue')

theta_6 = np.linspace(7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_6))
rho_2 = 0.8*abs(np.cos(2/7 * theta_6))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_6) + 1j * np.sin(theta_6))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'blue')

theta_7 = np.linspace(-np.pi/4 + 7*np.pi/2, 7*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_7))
rho_2 = 0.8*abs(np.cos(2/7 * theta_7))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_7) + 1j * np.sin(theta_7))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'mediumblue')

theta_8 = np.linspace(14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_1 = 0.3*abs(np.cos(3/4 * theta_8))
rho_2 = 0.8*abs(np.cos(2/7 * theta_8))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * (np.cos(theta_8) + 1j * np.sin(theta_8))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'darkblue')


#уберем лишнее
phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
lines = np.linspace(0, rho_1, 800)
z = lines * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'white')

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
lines = np.linspace(0, rho_1, 800)
z = lines * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'white')

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
lines = np.linspace(0, rho_1, 800)
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'white')


phi_1 = np.linspace(-np.pi/3, np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_2 = np.linspace(-np.pi/3 + 4*np.pi/3, np.pi/3 + 4*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_3 = np.linspace(-np.pi/3 + 8*np.pi/3, np.pi/3 + 8*np.pi/3, 800)
rho_1 = 0.3*abs(np.cos(3/4 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_4 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_5 = np.linspace(-np.pi/4 + 7*np.pi/2, np.pi/4 + 7*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_6 = np.linspace(-np.pi/4 + 14*np.pi/2, np.pi/4 + 14*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

phi_7 = np.linspace(-np.pi/4 + 21*np.pi/2, np.pi/4 + 21*np.pi/2, 800)
rho_2 = 0.8*abs(np.cos(2/7 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
g = (4*z + 1j*3)/(4 - 1j*3*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2.5)

plt.show()
